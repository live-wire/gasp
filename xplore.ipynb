# %% [markdown]
# # Exploratory analysis

# %%
!
# Out:
# HELSINKI_100x100m_3mo.nc4 xplore.ipynb

# %%
import xarray as xr
import datetime

dataset = "HELSINKI_100x100m_3mo.nc4"
xds = xr.open_dataset(dataset)
dimensions = set()
for k in xds.dims:
    dimensions.add(str(k))
dimensions
# Out:
# {'height', 'lat', 'lon', 'time'}

# %%
xds
# Out:
# <xarray.Dataset>
# Dimensions:            (height: 1, lat: 164, lon: 127, time: 26497)
# Coordinates:
#   * height             (height) float32 50.0
#   * lat                (lat) float32 60.12706 60.12796 ... 60.273193 60.274094
#   * lon                (lon) float32 24.831879 24.833687 ... 25.0577 25.059505
#   * time               (time) datetime64[ns] 2020-06-01 ... 2020-09-01
# Data variables:
#     fmi_no             (time, height, lat, lon) float32 ...
#     fmi_no2            (time, height, lat, lon) float32 ...
#     fmi_pm10p0         (time, height, lat, lon) float32 ...
#     fmi_pm2p5          (time, height, lat, lon) float32 ...
#     fmi_rel_humid      (time, height, lat, lon) float32 ...
#     fmi_so2            (time, height, lat, lon) float32 ...
#     fmi_temp_2m        (time, lat, lon) float32 ...
#     fmi_windspeed_10m  (time, lat, lon) float32 ...
#     megasense_aqi      (time, height, lat, lon) float32 ...
#     megasense_co       (time, height, lat, lon) float32 ...
#     megasense_no2      (time, height, lat, lon) float32 ...
#     megasense_o3       (time, height, lat, lon) float32 ...
#     megasense_pm10p0   (time, height, lat, lon) float32 ...
#     megasense_pm2p5    (time, height, lat, lon) float32 ...
# Attributes:
#     Conventions:            CF-1.3
#     SIMULATION_START_DATE:  2019-06-01T00:00:00Z
#     grid_projection:        lonlat
#     pole_lat:               -90.0
#     pole_lon:               0.0
#     title:                  MEGASENSE_SILAM_SIMULATION
#     source:                 SILAM v5_7 SVN (r590117) and MEGASENSE
#     NCO:                    netCDF Operators version 4.9.1 (Homepage = http:/...
#     authors:                Jonatan Hamberg<jonatan.hamberg@helsinki.fi>\nJoh...
#     history:                Tue Sep 22 11:03:30 2020: ncks -d lat,60.126977,6...

# %% [markdown]
# ## Time series database
# ### InfluxDB with Chronograph
# See: `influx.py`, `batcher.py`
#
# **InfluxClient** establishes a connection to the database.
#
# **Batcher** is implemented which sends updates to the database in batches for high throughput (Fast Writes)

# %%
def t4influx(s):
    s = s[:-3]
    t = datetime.datetime.strptime(s, '%Y-%m-%dT%H:%M:%S.%f')
    x = int(t.timestamp())
    while x<1e18:
        x = x*10
    return x

# %%
from influx import InfluxClient
tsd = InfluxClient()

tsd.send("mem,host=host1 used_percent=24.43234543 %s"%t4influx("2020-07-01T00:00:00.000000000"))
# Out:
# 1 items sent!

# %%
xds.loc[dict(lat=60.12706, lon=
24.831879, time="2020-07-01T00:00:00.000000000")].get("fmi_rel_humid").values[0]
# Out:
# 0.778756

# %%
variables = list(map(lambda x: str(x), xds.variables))
variables = list(filter(lambda x: x not in dimensions, variables))
item = lambda x: x.item() if isinstance(x, np.ndarray) else x
variables
# Out:
# ['fmi_no',
#  'fmi_no2',
#  'fmi_pm10p0',
#  'fmi_pm2p5',
#  'fmi_rel_humid',
#  'fmi_so2',
#  'fmi_temp_2m',
#  'fmi_windspeed_10m',
#  'megasense_aqi',
#  'megasense_co',
#  'megasense_no2',
#  'megasense_o3',
#  'megasense_pm10p0',
#  'megasense_pm2p5']

# %%
xds.time.values.min()
# Out:
# numpy.datetime64('2020-06-01T00:00:00.000000000')

# %%
def minMaxFinder(variables_local):
    ret = {}
    for v in variables_local:
        print("Finding minmax for:", v)
        mn = item(xds.get(v).min().values)
        mx = item(xds.get(v).max().values)
        ret[v] = [mn, mx]
        print(v, ret[v])
    return ret

minmax = minMaxFinder(variables)
minmax
# Out:
# Finding minmax for: fmi_no
# fmi_no [0.0, 61.811485290527344]
# Finding minmax for: fmi_no2
# fmi_no2 [0.0, 56.29759216308594]
# Finding minmax for: fmi_pm10p0
# fmi_pm10p0 [0.0, 283.2841491699219]
# Finding minmax for: fmi_pm2p5
# fmi_pm2p5 [0.0, 143.1856231689453]
# Finding minmax for: fmi_rel_humid
# fmi_rel_humid [0.2998336851596832, 1.0]
# Finding minmax for: fmi_so2
# fmi_so2 [0.0, 6.420897483825684]
# Finding minmax for: fmi_temp_2m
# fmi_temp_2m [281.22802734375, 300.3909912109375]
# Finding minmax for: fmi_windspeed_10m
# fmi_windspeed_10m [0.283974289894104, 11.144472122192383]
# Finding minmax for: megasense_aqi
# megasense_aqi [1.0, 5.0]
# Finding minmax for: megasense_co
# megasense_co [2701.974609375, 93823.6875]
# Finding minmax for: megasense_no2
# megasense_no2 [8.133000051202544e-07, 4854.54150390625]
# Finding minmax for: megasense_o3
# megasense_o3 [1.3320000391559006e-07, 4247.71875]
# Finding minmax for: megasense_pm10p0
# megasense_pm10p0 [1.7760099581209943e-05, 909.0736083984375]
# Finding minmax for: megasense_pm2p5
# megasense_pm2p5 [5.096000222692965e-06, 741.8656005859375]
# {'fmi_no': [0.0, 61.811485290527344],
#  'fmi_no2': [0.0, 56.29759216308594],
#  'fmi_pm10p0': [0.0, 283.2841491699219],
#  'fmi_pm2p5': [0.0, 143.1856231689453],
#  'fmi_rel_humid': [0.2998336851596832, 1.0],
#  'fmi_so2': [0.0, 6.420897483825684],
#  'fmi_temp_2m': [281.22802734375, 300.3909912109375],
#  'fmi_windspeed_10m': [0.283974289894104, 11.144472122192383],
#  'megasense_aqi': [1.0, 5.0],
#  'megasense_co': [2701.974609375, 93823.6875],
#  'megasense_no2': [8.133000051202544e-07, 4854.54150390625],
#  'megasense_o3': [1.3320000391559006e-07, 4247.71875],
#  'megasense_pm10p0': [1.7760099581209943e-05, 909.0736083984375],
#  'megasense_pm2p5': [5.096000222692965e-06, 741.8656005859375]}

# %%
from grid import Grid
g = Grid(xds.lat.values, xds.lon.values)
g.grid
# Out:
# {'cell_0_0': {'name': 'cell_0_0',
#   'polygon': [(60.12706, 24.831879), (60.14149, 24.853558)]},
#  'cell_0_1': {'name': 'cell_0_1',
#   'polygon': [(60.12706, 24.855364), (60.14149, 24.877043)]},
#  'cell_0_2': {'name': 'cell_0_2',
#   'polygon': [(60.12706, 24.878849), (60.14149, 24.900528)]},
#  'cell_0_3': {'name': 'cell_0_3',
#   'polygon': [(60.12706, 24.902336), (60.14149, 24.924013)]},
#  'cell_0_4': {'name': 'cell_0_4',
#   'polygon': [(60.12706, 24.925821), (60.14149, 24.947498)]},
#  'cell_0_5': {'name': 'cell_0_5',
#   'polygon': [(60.12706, 24.949306), (60.14149, 24.970984)]},
#  'cell_0_6': {'name': 'cell_0_6',
#   'polygon': [(60.12706, 24.972792), (60.14149, 24.994469)]},
#  'cell_0_7': {'name': 'cell_0_7',
#   'polygon': [(60.12706, 24.996277), (60.14149, 25.017956)]},
#  'cell_0_8': {'name': 'cell_0_8',
#   'polygon': [(60.12706, 25.019762), (60.14149, 25.041441)]},
#  'cell_0_9': {'name': 'cell_0_9',
#   'polygon': [(60.12706, 25.043247), (60.14149, 25.059505)]},
#  'cell_1_0': {'name': 'cell_1_0',
#   'polygon': [(60.142395, 24.831879), (60.156826, 24.853558)]},
#  'cell_1_1': {'name': 'cell_1_1',
#   'polygon': [(60.142395, 24.855364), (60.156826, 24.877043)]},
#  'cell_1_2': {'name': 'cell_1_2',
#   'polygon': [(60.142395, 24.878849), (60.156826, 24.900528)]},
#  'cell_1_3': {'name': 'cell_1_3',
#   'polygon': [(60.142395, 24.902336), (60.156826, 24.924013)]},
#  'cell_1_4': {'name': 'cell_1_4',
#   'polygon': [(60.142395, 24.925821), (60.156826, 24.947498)]},
#  'cell_1_5': {'name': 'cell_1_5',
#   'polygon': [(60.142395, 24.949306), (60.156826, 24.970984)]},
#  'cell_1_6': {'name': 'cell_1_6',
#   'polygon': [(60.142395, 24.972792), (60.156826, 24.994469)]},
#  'cell_1_7': {'name': 'cell_1_7',
#   'polygon': [(60.142395, 24.996277), (60.156826, 25.017956)]},
#  'cell_1_8': {'name': 'cell_1_8',
#   'polygon': [(60.142395, 25.019762), (60.156826, 25.041441)]},
#  'cell_1_9': {'name': 'cell_1_9',
#   'polygon': [(60.142395, 25.043247), (60.156826, 25.059505)]},
#  'cell_2_0': {'name': 'cell_2_0',
#   'polygon': [(60.15773, 24.831879), (60.17216, 24.853558)]},
#  'cell_2_1': {'name': 'cell_2_1',
#   'polygon': [(60.15773, 24.855364), (60.17216, 24.877043)]},
#  'cell_2_2': {'name': 'cell_2_2',
#   'polygon': [(60.15773, 24.878849), (60.17216, 24.900528)]},
#  'cell_2_3': {'name': 'cell_2_3',
#   'polygon': [(60.15773, 24.902336), (60.17216, 24.924013)]},
#  'cell_2_4': {'name': 'cell_2_4',
#   'polygon': [(60.15773, 24.925821), (60.17216, 24.947498)]},
#  'cell_2_5': {'name': 'cell_2_5',
#   'polygon': [(60.15773, 24.949306), (60.17216, 24.970984)]},
#  'cell_2_6': {'name': 'cell_2_6',
#   'polygon': [(60.15773, 24.972792), (60.17216, 24.994469)]},
#  'cell_2_7': {'name': 'cell_2_7',
#   'polygon': [(60.15773, 24.996277), (60.17216, 25.017956)]},
#  'cell_2_8': {'name': 'cell_2_8',
#   'polygon': [(60.15773, 25.019762), (60.17216, 25.041441)]},
#  'cell_2_9': {'name': 'cell_2_9',
#   'polygon': [(60.15773, 25.043247), (60.17216, 25.059505)]},
#  'cell_3_0': {'name': 'cell_3_0',
#   'polygon': [(60.173065, 24.831879), (60.187496, 24.853558)]},
#  'cell_3_1': {'name': 'cell_3_1',
#   'polygon': [(60.173065, 24.855364), (60.187496, 24.877043)]},
#  'cell_3_2': {'name': 'cell_3_2',
#   'polygon': [(60.173065, 24.878849), (60.187496, 24.900528)]},
#  'cell_3_3': {'name': 'cell_3_3',
#   'polygon': [(60.173065, 24.902336), (60.187496, 24.924013)]},
#  'cell_3_4': {'name': 'cell_3_4',
#   'polygon': [(60.173065, 24.925821), (60.187496, 24.947498)]},
#  'cell_3_5': {'name': 'cell_3_5',
#   'polygon': [(60.173065, 24.949306), (60.187496, 24.970984)]},
#  'cell_3_6': {'name': 'cell_3_6',
#   'polygon': [(60.173065, 24.972792), (60.187496, 24.994469)]},
#  'cell_3_7': {'name': 'cell_3_7',
#   'polygon': [(60.173065, 24.996277), (60.187496, 25.017956)]},
#  'cell_3_8': {'name': 'cell_3_8',
#   'polygon': [(60.173065, 25.019762), (60.187496, 25.041441)]},
#  'cell_3_9': {'name': 'cell_3_9',
#   'polygon': [(60.173065, 25.043247), (60.187496, 25.059505)]},
#  'cell_4_0': {'name': 'cell_4_0',
#   'polygon': [(60.1884, 24.831879), (60.20283, 24.853558)]},
#  'cell_4_1': {'name': 'cell_4_1',
#   'polygon': [(60.1884, 24.855364), (60.20283, 24.877043)]},
#  'cell_4_2': {'name': 'cell_4_2',
#   'polygon': [(60.1884, 24.878849), (60.20283, 24.900528)]},
#  'cell_4_3': {'name': 'cell_4_3',
#   'polygon': [(60.1884, 24.902336), (60.20283, 24.924013)]},
#  'cell_4_4': {'name': 'cell_4_4',
#   'polygon': [(60.1884, 24.925821), (60.20283, 24.947498)]},
#  'cell_4_5': {'name': 'cell_4_5',
#   'polygon': [(60.1884, 24.949306), (60.20283, 24.970984)]},
#  'cell_4_6': {'name': 'cell_4_6',
#   'polygon': [(60.1884, 24.972792), (60.20283, 24.994469)]},
#  'cell_4_7': {'name': 'cell_4_7',
#   'polygon': [(60.1884, 24.996277), (60.20283, 25.017956)]},
#  'cell_4_8': {'name': 'cell_4_8',
#   'polygon': [(60.1884, 25.019762), (60.20283, 25.041441)]},
#  'cell_4_9': {'name': 'cell_4_9',
#   'polygon': [(60.1884, 25.043247), (60.20283, 25.059505)]},
#  'cell_5_0': {'name': 'cell_5_0',
#   'polygon': [(60.203735, 24.831879), (60.218166, 24.853558)]},
#  'cell_5_1': {'name': 'cell_5_1',
#   'polygon': [(60.203735, 24.855364), (60.218166, 24.877043)]},
#  'cell_5_2': {'name': 'cell_5_2',
#   'polygon': [(60.203735, 24.878849), (60.218166, 24.900528)]},
#  'cell_5_3': {'name': 'cell_5_3',
#   'polygon': [(60.203735, 24.902336), (60.218166, 24.924013)]},
#  'cell_5_4': {'name': 'cell_5_4',
#   'polygon': [(60.203735, 24.925821), (60.218166, 24.947498)]},
#  'cell_5_5': {'name': 'cell_5_5',
#   'polygon': [(60.203735, 24.949306), (60.218166, 24.970984)]},
#  'cell_5_6': {'name': 'cell_5_6',
#   'polygon': [(60.203735, 24.972792), (60.218166, 24.994469)]},
#  'cell_5_7': {'name': 'cell_5_7',
#   'polygon': [(60.203735, 24.996277), (60.218166, 25.017956)]},
#  'cell_5_8': {'name': 'cell_5_8',
#   'polygon': [(60.203735, 25.019762), (60.218166, 25.041441)]},
#  'cell_5_9': {'name': 'cell_5_9',
#   'polygon': [(60.203735, 25.043247), (60.218166, 25.059505)]},
#  'cell_6_0': {'name': 'cell_6_0',
#   'polygon': [(60.21907, 24.831879), (60.2335, 24.853558)]},
#  'cell_6_1': {'name': 'cell_6_1',
#   'polygon': [(60.21907, 24.855364), (60.2335, 24.877043)]},
#  'cell_6_2': {'name': 'cell_6_2',
#   'polygon': [(60.21907, 24.878849), (60.2335, 24.900528)]},
#  'cell_6_3': {'name': 'cell_6_3',
#   'polygon': [(60.21907, 24.902336), (60.2335, 24.924013)]},
#  'cell_6_4': {'name': 'cell_6_4',
#   'polygon': [(60.21907, 24.925821), (60.2335, 24.947498)]},
#  'cell_6_5': {'name': 'cell_6_5',
#   'polygon': [(60.21907, 24.949306), (60.2335, 24.970984)]},
#  'cell_6_6': {'name': 'cell_6_6',
#   'polygon': [(60.21907, 24.972792), (60.2335, 24.994469)]},
#  'cell_6_7': {'name': 'cell_6_7',
#   'polygon': [(60.21907, 24.996277), (60.2335, 25.017956)]},
#  'cell_6_8': {'name': 'cell_6_8',
#   'polygon': [(60.21907, 25.019762), (60.2335, 25.041441)]},
#  'cell_6_9': {'name': 'cell_6_9',
#   'polygon': [(60.21907, 25.043247), (60.2335, 25.059505)]},
#  'cell_7_0': {'name': 'cell_7_0',
#   'polygon': [(60.234406, 24.831879), (60.248837, 24.853558)]},
#  'cell_7_1': {'name': 'cell_7_1',
#   'polygon': [(60.234406, 24.855364), (60.248837, 24.877043)]},
#  'cell_7_2': {'name': 'cell_7_2',
#   'polygon': [(60.234406, 24.878849), (60.248837, 24.900528)]},
#  'cell_7_3': {'name': 'cell_7_3',
#   'polygon': [(60.234406, 24.902336), (60.248837, 24.924013)]},
#  'cell_7_4': {'name': 'cell_7_4',
#   'polygon': [(60.234406, 24.925821), (60.248837, 24.947498)]},
#  'cell_7_5': {'name': 'cell_7_5',
#   'polygon': [(60.234406, 24.949306), (60.248837, 24.970984)]},
#  'cell_7_6': {'name': 'cell_7_6',
#   'polygon': [(60.234406, 24.972792), (60.248837, 24.994469)]},
#  'cell_7_7': {'name': 'cell_7_7',
#   'polygon': [(60.234406, 24.996277), (60.248837, 25.017956)]},
#  'cell_7_8': {'name': 'cell_7_8',
#   'polygon': [(60.234406, 25.019762), (60.248837, 25.041441)]},
#  'cell_7_9': {'name': 'cell_7_9',
#   'polygon': [(60.234406, 25.043247), (60.248837, 25.059505)]},
#  'cell_8_0': {'name': 'cell_8_0',
#   'polygon': [(60.24974, 24.831879), (60.26417, 24.853558)]},
#  'cell_8_1': {'name': 'cell_8_1',
#   'polygon': [(60.24974, 24.855364), (60.26417, 24.877043)]},
#  'cell_8_2': {'name': 'cell_8_2',
#   'polygon': [(60.24974, 24.878849), (60.26417, 24.900528)]},
#  'cell_8_3': {'name': 'cell_8_3',
#   'polygon': [(60.24974, 24.902336), (60.26417, 24.924013)]},
#  'cell_8_4': {'name': 'cell_8_4',
#   'polygon': [(60.24974, 24.925821), (60.26417, 24.947498)]},
#  'cell_8_5': {'name': 'cell_8_5',
#   'polygon': [(60.24974, 24.949306), (60.26417, 24.970984)]},
#  'cell_8_6': {'name': 'cell_8_6',
#   'polygon': [(60.24974, 24.972792), (60.26417, 24.994469)]},
#  'cell_8_7': {'name': 'cell_8_7',
#   'polygon': [(60.24974, 24.996277), (60.26417, 25.017956)]},
#  'cell_8_8': {'name': 'cell_8_8',
#   'polygon': [(60.24974, 25.019762), (60.26417, 25.041441)]},
#  'cell_8_9': {'name': 'cell_8_9',
#   'polygon': [(60.24974, 25.043247), (60.26417, 25.059505)]},
#  'cell_9_0': {'name': 'cell_9_0',
#   'polygon': [(60.265076, 24.831879), (60.274094, 24.853558)]},
#  'cell_9_1': {'name': 'cell_9_1',
#   'polygon': [(60.265076, 24.855364), (60.274094, 24.877043)]},
#  'cell_9_2': {'name': 'cell_9_2',
#   'polygon': [(60.265076, 24.878849), (60.274094, 24.900528)]},
#  'cell_9_3': {'name': 'cell_9_3',
#   'polygon': [(60.265076, 24.902336), (60.274094, 24.924013)]},
#  'cell_9_4': {'name': 'cell_9_4',
#   'polygon': [(60.265076, 24.925821), (60.274094, 24.947498)]},
#  'cell_9_5': {'name': 'cell_9_5',
#   'polygon': [(60.265076, 24.949306), (60.274094, 24.970984)]},
#  'cell_9_6': {'name': 'cell_9_6',
#   'polygon': [(60.265076, 24.972792), (60.274094, 24.994469)]},
#  'cell_9_7': {'name': 'cell_9_7',
#   'polygon': [(60.265076, 24.996277), (60.274094, 25.017956)]},
#  'cell_9_8': {'name': 'cell_9_8',
#   'polygon': [(60.265076, 25.019762), (60.274094, 25.041441)]},
#  'cell_9_9': {'name': 'cell_9_9',
#   'polygon': [(60.265076, 25.043247), (60.274094, 25.059505)]}}

# %%
import statistics
import math
import numpy as np

def gridLatLongs(lats, longs):
    ret = []
    for la in lats:
        for lo in longs:
            ret.append((la,lo))
            break # Just take the first value from the combination # Instead if mean computation
        break
    return ret

def processCell(t):
    llats = g.llats
    llongs = g.llongs
    for i in range(len(llats)):
        for j in range(len(llongs)):
            lls = gridLatLongs(llats[i], llongs[j])
            cell = "cell_%d_%d"%(i,j)
            fieldSet = getFieldSet(t, lls, statistics.mean)
            polygon = str(g.grid[cell]['polygon']).replace(" ", "")
            polygon = polygon.strip("[)(\[\]]")
            polygon = polygon.replace("),(", "__")
            polygon = polygon.replace(",", "_")
            r = "vwa,grid=%s,polygon=%s %s %d"%(cell, polygon, fieldSet, t4influx(t))
            # print(r)
            tsd.send(r)

def t4influx(s):
    s = s[:-3]
    t = datetime.datetime.strptime(s, '%Y-%m-%dT%H:%M:%S.%f')
    x = int(t.timestamp())
    while x<1e18:
        x = x*10
    return x

def getFieldSet(t, lls, reducer=statistics.mean):
    d = dict()
    for v in variables:
        d[v] = []

    for lat, lon in lls:
        for v in variables:
            dlocal = dict(lat=lat, lon=lon, time=t)
            valueObj = xds.loc[dlocal].get(v).values
            # print(v, type(valueObj), valueObj)
            if isinstance(valueObj, np.ndarray): 
                val = valueObj.item()
            else:
                val = valueObj
            val = 0.0 if math.isnan(val) else val
            d[v].append(val)
            
    fields = ""
    for v in variables:
        s = "%s=%f"%(v, reducer(d[v]))
        s = s.replace(" ", "_") # Just to be sure
        fields = fields + ("" if not len(fields) else ",") + s
    return fields

# %%
import statistics
from multiprocessing import Pool

def f(x):
    return x*x

if __name__ == '__main__':
    p = Pool(8)
    print(p.map(f, [1, 2, 3]))

    
for i,t in enumerate(xds.time.values):
    if i%3 == 0:
        processCell(str(t), g.llats, g.llongs)
    if i%500==0:
        pr = (len(xds.time.values)-i)*100//len(xds.time.values)
        print("Pushed till:%s, Remaining: %d percent"%(t, pr))
# Out:
# 15 items sent!
# 78 items sent!
# Pushed till:2020-06-01T00:00:00.000000000, Remaining: 100 percent
# 77 items sent!
# 76 items sent!
# 77 items sent!
# 78 items sent!
# 77 items sent!
# 78 items sent!
# 77 items sent!
# 77 items sent!
# 77 items sent!
# 77 items sent!
# 77 items sent!
# 76 items sent!
# 77 items sent!
# 77 items sent!
# 78 items sent!
# 77 items sent!
# 78 items sent!
# 73 items sent!
# 77 items sent!
# 77 items sent!
# 77 items sent!
# 77 items sent!
# 76 items sent!
# 77 items sent!
# 72 items sent!
# 71 items sent!
# 76 items sent!
# 77 items sent!
# 77 items sent!
# 78 items sent!
# 77 items sent!
# 77 items sent!
# 78 items sent!
# 67 items sent!
# 66 items sent!
# 72 items sent!
# 78 items sent!
# 70 items sent!
# 75 items sent!
# 77 items sent!
# 77 items sent!
# 78 items sent!
# 78 items sent!
# 77 items sent!
# 78 items sent!
# 78 items sent!
# 76 items sent!
# 78 items sent!
# 76 items sent!
# 77 items sent!
# 77 items sent!
# 77 items sent!
# 77 items sent!
# 77 items sent!
# 78 items sent!
# 78 items sent!
# 77 items sent!
# 73 items sent!
# 78 items sent!
# 77 items sent!
# 77 items sent!
# 76 items sent!
# 76 items sent!
# 77 items sent!
# 77 items sent!
# 77 items sent!
# 77 items sent!
# 66 items sent!
# 66 items sent!
# 62 items sent!
# 68 items sent!
# 71 items sent!
# 72 items sent!
# 68 items sent!
# 74 items sent!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-111-b664226d2b4d> in <module>
#       3 for i,t in enumerate(xds.time.values):
#       4     if i%3 == 0:
# ----> 5         processCell(str(t), g.llats, g.llongs)
#       6     if i%500==0:
#       7         pr = (len(xds.time.values)-i)*100//len(xds.time.values)
#
# <ipython-input-109-ea82079229af> in processCell(t, llats, llongs)
#      17             lls = gridLatLongs(llats[i], llongs[j])
#      18             cell = "cell_%d_%d"%(i,j)
# ---> 19             fieldSet = getFieldSet(t, lls, statistics.mean)
#      20             polygon = str(g.grid[cell]['polygon']).replace(" ", "")
#      21             polygon = polygon.strip("[)(\[\]]")
#
# <ipython-input-109-ea82079229af> in getFieldSet(t, lls, reducer)
#      42         for v in variables:
#      43             dlocal = dict(lat=lat, lon=lon, time=t)
# ---> 44             valueObj = xds.loc[dlocal].get(v).values
#      45             # print(v, type(valueObj), valueObj)
#      46             if isinstance(valueObj, np.ndarray):
#
# ~/bapc/venv3/lib/python3.7/site-packages/xarray/core/dataset.py in __getitem__(self, key)
#     423         if not utils.is_dict_like(key):
#     424             raise TypeError("can only lookup dictionaries from Dataset.loc")
# --> 425         return self.dataset.sel(key)
#     426
#     427
#
# ~/bapc/venv3/lib/python3.7/site-packages/xarray/core/dataset.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2104         indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
#    2105         pos_indexers, new_indexes = remap_label_indexers(
# -> 2106             self, indexers=indexers, method=method, tolerance=tolerance
#    2107         )
#    2108         result = self.isel(indexers=pos_indexers, drop=drop)
#
# ~/bapc/venv3/lib/python3.7/site-packages/xarray/core/coordinates.py in remap_label_indexers(obj, indexers, method, tolerance, **indexers_kwargs)
#     396
#     397     pos_indexers, new_indexes = indexing.remap_label_indexers(
# --> 398         obj, v_indexers, method=method, tolerance=tolerance
#     399     )
#     400     # attach indexer's coordinate to pos_indexers
#
# ~/bapc/venv3/lib/python3.7/site-packages/xarray/core/indexing.py in remap_label_indexers(data_obj, indexers, method, tolerance)
#     257     new_indexes = {}
#     258
# --> 259     dim_indexers = get_dim_indexers(data_obj, indexers)
#     260     for dim, label in dim_indexers.items():
#     261         try:
#
# ~/bapc/venv3/lib/python3.7/site-packages/xarray/core/indexing.py in get_dim_indexers(data_obj, indexers)
#     228     dim_indexers = {}
#     229     for key, label in indexers.items():
# --> 230         (dim,) = data_obj[key].dims
#     231         if key != dim:
#     232             # assume here multi-index level indexer
#
# ~/bapc/venv3/lib/python3.7/site-packages/xarray/core/dataset.py in __getitem__(self, key)
#    1270
#    1271         if hashable(key):
# -> 1272             return self._construct_dataarray(key)
#    1273         else:
#    1274             return self._copy_listed(np.asarray(key))
#
# ~/bapc/venv3/lib/python3.7/site-packages/xarray/core/dataset.py in _construct_dataarray(self, name)
#    1167     def _construct_dataarray(self, name: Hashable) -> "DataArray":
#    1168         """Construct a DataArray by indexing this dataset"""
# -> 1169         from .dataarray import DataArray
#    1170
#    1171         try:
#
# ~/bapc/venv3/lib/python3.7/importlib/_bootstrap.py in parent(self)
#
# KeyboardInterrupt:
